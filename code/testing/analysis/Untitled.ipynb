# %% [markdown]
# # Analysis

# %%
import mne
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Simple Plot

# %% [markdown]
# ### Import Data

# %%
filename = input("What file do you want to plot? ")
path_to_file = "../data/"
path = path_to_file + filename
# Out:
# What file do you want to plot?BCIproject_trial-6_raw.fif.gz

# %%
print(path)
# Out:
# ../data/BCIproject_trial-6_raw.fif.gz

# %%
raw = mne.io.read_raw_fif(path, preload=True, verbose=0)

# %%
data = raw.get_data()

# %% [markdown]
# ### Plot Data

# %%
X = np.linspace(0, np.shape(data)[1], np.shape(data)[1])
Y = data[0]

plt.plot(X, Y)
plt.title("Data in Samples");
